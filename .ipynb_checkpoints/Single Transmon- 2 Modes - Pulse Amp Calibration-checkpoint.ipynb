# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output

# %%
from qutip import *

# %% [markdown]
# ### Introduction
#
# The Hamiltonian for a Transmon qubit is
#
# $\displaystyle H = \sum_n 4 E_C (n_g - n)^2 \left|n\right\rangle\left\langle n\right| - E_{J\Sigma} [\cos(\pi \Phi/\Phi_0)\cos(\theta) + d \sin(\pi \Phi/\Phi_0)\sin(\theta)]$
#
# $\displaystyle H = \sum_n 4 E_C (n_g - n)^2 \left|n\right\rangle\left\langle n\right| - E_{J\Sigma}[\cos(\pi \Phi/\Phi_0)\frac{1}{2}\sum_n\left(\left|n+1\right\rangle\left\langle n\right| + \left|n\right\rangle\left\langle n+1\right| \right)+i d \sin(\pi \Phi/\Phi_0)\frac{1}{2}\sum_n\left(\left|n+1\right\rangle\left\langle n\right| - \left|n\right\rangle\left\langle n+1\right| \right)]$
#
# where $E_C$ is the charge energy, $E_J$ is the Josephson energy, and $\left| n\right\rangle$ is the charge state with $n$ Cooper-pairs on the island that makes up the charge qubit.

# %% [markdown]
# ### Qubit parameters

# %%
class SystemParameters:
    
    def __init__(self):
        # Input variable
        
        self.init_system()
        self.init_operators()
        self.state_operators()
        
    def init_system(self):
        self.initial_pulse = True
        self.qubit_state_num = 3
        self.alpha = 0.224574
        self.freq_ge = 3.9225 #GHz
        self.ens = np.array([ 2*np.pi*ii*(self.freq_ge - 0.5*(ii-1)*self.alpha) for ii in np.arange(self.qubit_state_num)])
        
        self.mode_state_num = 3
        
        self.qm_g1 = 2*np.pi*0.075 #GHz
        self.mode1_freq = 6.11 #GHz
        self.mode1_ens = np.array([ 2*np.pi*ii*(self.mode1_freq) for ii in np.arange(self.mode_state_num)])
        
        self.qm_g2 = 2*np.pi*0.075 #GHz
        self.mode2_freq = 6.65 #GHz
        self.mode2_ens = np.array([ 2*np.pi*ii*(self.mode2_freq) for ii in np.arange(self.mode_state_num)])
        
        self.state_num = self.qubit_state_num * (self.mode_state_num**2)
        
        self.pts_per_period = 40
        self.dt = (1./self.mode2_freq)/self.pts_per_period
        self.total_time=200.
        self.steps = int(self.total_time/self.dt)+1
        self.tlist = np.linspace(0,self.total_time,self.steps)
        
    def update_total_time(self,total_time):
        self.total_time=total_time
        self.steps = int(self.total_time/self.dt)+1
        self.tlist = np.linspace(0,self.total_time,self.steps)
        
    def update_pts_per_period(self,pts_per_period):
        self.pts_per_period=pts_per_period
        self.dt = (1./self.mode_freq)/self.pts_per_period
        self.steps = int(self.total_time/self.dt)+1
        self.tlist = np.linspace(0,self.total_time,self.steps)
        
    def init_operators(self):
        # Create operator matrix in numpy array
        H_q = np.diag(self.ens)
        H_m1 = np.diag(self.mode1_ens)
        H_m2 = np.diag(self.mode2_ens)
        
        Q_x   = np.diag(np.sqrt(np.arange(1,self.qubit_state_num)),1)+np.diag(np.sqrt(np.arange(1,self.qubit_state_num)),-1)
        Q_y   = (0+1j) *(np.diag(np.sqrt(np.arange(1,self.qubit_state_num)),1)-np.diag(np.sqrt(np.arange(1,self.qubit_state_num)),-1))
        Q_z   = np.diag(np.arange(0,self.qubit_state_num))
        
        M_x = np.diag(np.sqrt(np.arange(1,self.mode_state_num)),1)+np.diag(np.sqrt(np.arange(1,self.mode_state_num)),-1)
        
        self.I_q = np.identity(self.qubit_state_num)
        self.I_m = np.identity(self.mode_state_num)
        
        XI = np.kron(Q_x,np.kron(self.I_m,self.I_m))
        YI = np.kron(Q_y,np.kron(self.I_m,self.I_m))
        ZI = np.kron(Q_z,np.kron(self.I_m,self.I_m))
        
        self.ops = [XI,YI,ZI]
        
        self.Hx_op = XI
        self.Hy_op = YI
        self.Hz_op = ZI
        
        self.ops_len = len(self.ops)
        
        self.H0 = np.kron(H_q,np.kron(self.I_m,self.I_m)) + np.kron(self.I_q,np.kron(H_m1,self.I_m)) +\
            np.kron(self.I_q,np.kron(self.I_m,H_m2)) + self.qm_g1*np.kron(Q_x,np.kron(M_x,self.I_m)) +\
            self.qm_g2*np.kron(Q_x,np.kron(self.I_m,M_x))
       
    def state_operators(self):
        # State operators, used for output
        g_array= np.zeros(self.qubit_state_num)
        g_array[0] = 1
        g_vector = tensor(Qobj(np.array(g_array)),Qobj(self.I_m),Qobj(self.I_m))
        g_matrix = tensor(Qobj(np.diag(g_array)),Qobj(self.I_m),Qobj(self.I_m))

        e_array= np.zeros(self.qubit_state_num)
        e_array[1] = 1
        e_vector = tensor(Qobj(np.array(e_array)),Qobj(self.I_m),Qobj(self.I_m))
        e_matrix = tensor(Qobj(np.diag(e_array)),Qobj(self.I_m),Qobj(self.I_m))

        f_array= np.zeros(self.qubit_state_num)
        f_array[2] = 1
        f_vector = tensor(Qobj(np.array(f_array)),Qobj(self.I_m),Qobj(self.I_m))
        f_matrix = tensor(Qobj(np.diag(f_array)),Qobj(self.I_m),Qobj(self.I_m))
        
        
        H0 = Qobj(self.H0)
        
        self.g00 = H0.eigenstates()[1][0]*H0.eigenstates()[1][0].dag()
        self.e00 = H0.eigenstates()[1][1]*H0.eigenstates()[1][1].dag()
        self.g10 = H0.eigenstates()[1][2]*H0.eigenstates()[1][2].dag()
        self.g01 = H0.eigenstates()[1][3]*H0.eigenstates()[1][3].dag()
        self.f00 = H0.eigenstates()[1][4]*H0.eigenstates()[1][4].dag()
        self.e10 = H0.eigenstates()[1][5]*H0.eigenstates()[1][5].dag()
        self.e01 = H0.eigenstates()[1][6]*H0.eigenstates()[1][6].dag()
        self.g11 = H0.eigenstates()[1][8]*H0.eigenstates()[1][8].dag()

        
        self.gs = g_vector
        self.es = e_vector
        self.fs = f_vector

        return [self.g00,self.e00,self.g10,self.g01,self.f00,self.e10,self.e01,self.g11]
    
    
    def c_operators(self):
        # qubit coherence parameters

        T1_ge = 18000.0
        T1_ef = 7000.0
        T2_ge = 12000.0
        T2_ef = 12000.0
        T_ephi = 1/(1/T2_ge -1/(2*T1_ge))
        T_fphi = 1/(1/T2_ef -1/(2*T1_ef))
        
        # cavity coherence_parameters
        T1_cav1 = 4000.0
        T1_cav2 = 4000.0
        kappa1 = 1/T1_cav1 # cavity dissipation rate
        kappa2 = 1/T1_cav2 # cavity dissipation rate
        
        a1  = tensor(qeye(self.qubit_state_num),destroy(self.mode_state_num),qeye(self.mode_state_num))
        a2  = tensor(qeye(self.qubit_state_num),qeye(self.mode_state_num),destroy(self.mode_state_num))

        c_ops = (1/T1_ge)*lindblad_dissipator(self.gs*self.es.dag()) +   (1/T1_ef)*lindblad_dissipator(self.es*self.fs.dag()) +\
        (2/(T_ephi))*lindblad_dissipator(self.es*self.es.dag()) + (2/(T_fphi))*lindblad_dissipator(self.fs*self.fs.dag()) +\
        + (1/(T1_cav1))*lindblad_dissipator(a1)+ (1/(T1_cav2))*lindblad_dissipator(a2)
        
        return c_ops
    
    def time_to_index(self,time):
        return int(time/self.dt - 1)

# %%
sys_para = SystemParameters()
print Qobj(sys_para.H0).eigenstates()[0]/(2*np.pi)
# Out:
# [ -1.09333835e-03   3.91563935e+00   6.11090738e+00   6.65044011e+00
#    7.61195747e+00   1.00271505e+01   1.05668412e+01   1.22245836e+01
#    1.27624404e+01   1.33035656e+01   1.37184640e+01   1.42592779e+01
#    1.61497520e+01   1.66783416e+01   1.72274496e+01   1.88761038e+01
#    1.94155887e+01   1.98388814e+01   2.03657972e+01   2.09179817e+01
#    2.28009216e+01   2.33389468e+01   2.55292597e+01   2.64861502e+01
#    2.70245446e+01   2.94615449e+01   3.31448963e+01]

# %%
class H_Pulse:
    def __init__(self, sys_para):
        self.sys_para = sys_para
        self.tlist = self.sys_para.tlist
        self.pulse_coeff_array = np.zeros(len(self.tlist))
        
    def gauss_span_length(self,length):
        spacing = 5
        return 4*length + spacing

    def square_span_length(self,length):
        spacing = 5
        ramp_sigma = 10
        return length + 4*ramp_sigma + spacing

    def gauss(self,tlist,time,amp,freq,length,phase):
        span_length = self.gauss_span_length(length)
        t0 = time+0.5*span_length
        return amp*np.exp(-(tlist-t0)**2/(2*length**2)) * (tlist>time) * (tlist< (time+span_length)) *\
        np.sin(2*np.pi*freq*tlist + phase)
        
    def square(self,tlist,time,amp,freq,length,phase):
        ramp_sigma = 10
        span_length = self.gauss_span_length(length)
        t0 = time+2*ramp_sigma
        pulse = amp*np.exp(-(tlist-t0)**2/(2*ramp_sigma**2)) * (tlist>time) * (tlist<= t0) *\
        np.sin(2*np.pi*freq*tlist + phase)
        pulse = pulse + amp*(tlist>t0) * (tlist<= (t0+length)) * np.sin(2*np.pi*freq*tlist  +phase)
        pulse = pulse + amp*np.exp(-(tlist-(t0+length))**2/(2*ramp_sigma**2)) * (tlist>t0+length) * (tlist<= t0+length+2*ramp_sigma) *\
        np.sin(2*np.pi*freq*tlist +phase)
        
        return pulse
        
    def add_pulse(self,time,amp,freq,length,phase,ptype):
        if ptype == "gauss":
            self.pulse_coeff_array += self.gauss(self.tlist,time,amp,freq,length,phase)
            return time + self.gauss_span_length(length)
        elif ptype == "square":
            self.pulse_coeff_array += self.square(self.tlist,time,amp,freq,length,phase)
            return time + self.square_span_length(length)
    
    def add_arb_pulse(self,arb_pulse):
        c = self.pulse_coeff_array.copy()
        c[:len(arb_pulse)] += arb_pulse
        self.pulse_coeff_array = c
        
    def get_coeff(self,time):
        index = self.sys_para.time_to_index(time)
        return self.pulse_coeff_array[index]

# %%
def plot_result(output,sys_para):
    # Plotting
    # [self.g00,self.e00,self.g10,self.g01,self.e10,self.e01,self.g11]
    g00_out = output.expect[0]
    e00_out= output.expect[1]
    g10_out = output.expect[2]
    g01_out = output.expect[3]
    f00_out = output.expect[4]
    e10_out = output.expect[5]
    e01_out = output.expect[6]
    g11_out = output.expect[7]
    

    fig, axes = plt.subplots(1, 1, figsize=(10,6))

    axes.plot(sys_para.tlist, g00_out, label="g00")
    axes.plot(sys_para.tlist, e00_out, label="e00")
    axes.plot(sys_para.tlist, g10_out, label="g10")
    axes.plot(sys_para.tlist, g01_out, label="g01")
    axes.plot(sys_para.tlist, f00_out, label="f00")
    axes.plot(sys_para.tlist, e10_out, label="e10")
    axes.plot(sys_para.tlist, e01_out, label="e01")
    axes.plot(sys_para.tlist, g11_out, label="g11")
    axes.legend(loc=0)
    axes.set_xlabel('Time')
    axes.set_ylabel('Occupation probability')

# %%
def plot_sweep_result(p_g,p_e,tlist,sweep):
    plt.figure(figsize=(20,8))

    plt.subplot(121, title="g")

    plt.pcolormesh(tlist,sweep, np.array(p_g))
    plt.xlabel('Time')

    plt.subplot(122, title="e")

    plt.pcolormesh(tlist,sweep, np.array(p_e))
    plt.xlabel('Time')

# %% [markdown]
# ### Info

# %%
pi_length = 24.2
pi_amp = 0.0542
ef_pi_length = 9.4
ef_pi_amp = 0.099

sb1_pi_length = 24.
sb1_pi_amp = 0.307
sb1_2pi_length = 90.
sb1_2pi_amp = 0.26
sb1_ef_pi_length = 26.5
sb1_ef_pi_amp = 0.227
sb1_ef_2pi_length = 75.
sb1_ef_2pi_amp = 0.115

sb2_pi_length = 17.
sb2_pi_amp = 0.445
sb2_2pi_length = 58.
sb2_2pi_amp = 0.445
sb2_ef_pi_length = 75
sb2_ef_pi_amp = 0.14
sb2_ef_2pi_length = 177.
sb2_ef_2pi_amp = 0.07

# %% [markdown]
# ### Rabi

# %%
def Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)

    target_time = 24.2
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    
    if not sweep:
        Hx_pulse.add_pulse(time=0,amp=0.0542,freq=drive_freq /(2*np.pi),length=target_time,phase=np.pi/2,ptype="gauss")
    else:
        Hx_pulse.add_pulse(time=0,amp=amp,freq=drive_freq /(2*np.pi),length=target_time,phase=np.pi/2,ptype="gauss")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[0] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[1][sys_para.steps-1]
    print "Pi-pulse: " + str(fidelity)
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(100)
Rabi(sys_para)

# %% [markdown]
# ### Rabi Sweep for Pi-Pulse

# %%
def Rabi_sweep(sys_para):
    p_g = []
    p_e = []
    fid = []
    amp_list = np.linspace(0.054,0.056,11)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Rabi(sys_para, sweep = True, amp=amp)
        p_g.append(output.expect[0])
        p_e.append(output.expect[1])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(100)
[amp_list,fid] = Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### EF Rabi

# %%
def EF_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)

    target_time = 9.4
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][4] - H0.eigenstates()[0][1]
    
    if not sweep:
        Hx_pulse.add_pulse(time=0,amp=0.099,freq=drive_freq /(2*np.pi),length=target_time,phase=np.pi/2,ptype="gauss")
    else:
        Hx_pulse.add_pulse(time=0,amp=amp,freq=drive_freq /(2*np.pi),length=target_time,phase=np.pi/2,ptype="gauss")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[1] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[4][sys_para.steps-1]
    print "Pi-pulse: " + str(fidelity)
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(50)
EF_Rabi(sys_para)
# Out:
# Pi-pulse: 0.994527397996
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.99452739799594159)

# %%
def EF_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.093,0.103,11)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = EF_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(100)
[amp_list,fid] = EF_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband Rabi 1 Pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    flux_freq1 = H0.eigenstates()[0][2] - H0.eigenstates()[0][1]
    flux_freq2 = H0.eigenstates()[0][3] - H0.eigenstates()[0][1]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*sb1_pi_amp,freq=flux_freq1/(2*np.pi),length=sb1_pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=flux_freq1/(2*np.pi),length=sb1_pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[1] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[1][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(200)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.00070703128554231093)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.30,0.32,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(200)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband Rabi 2 Pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    flux_freq1 = H0.eigenstates()[0][2] - H0.eigenstates()[0][1]
    flux_freq2 = H0.eigenstates()[0][3] - H0.eigenstates()[0][1]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*0.46,freq=flux_freq2/(2*np.pi),length=sb2_pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=flux_freq2/(2*np.pi),length=sb2_pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[1] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[1][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(200)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.0030361578382095936)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.44,0.46,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(200)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband Rabi 1 2 pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    flux_freq1 = H0.eigenstates()[0][2] - H0.eigenstates()[0][1]
    flux_freq2 = H0.eigenstates()[0][3] - H0.eigenstates()[0][1]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*sb1_2pi_amp,freq=flux_freq1/(2*np.pi),length=sb1_2pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=flux_freq1/(2*np.pi),length=sb1_2pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[1] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[1][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(140)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.97929893722325789)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.25,0.27,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(150)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband Rabi 2 2pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    flux_freq1 = H0.eigenstates()[0][2] - H0.eigenstates()[0][1]
    flux_freq2 = H0.eigenstates()[0][3] - H0.eigenstates()[0][1]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*sb2_2pi_amp,freq=flux_freq2/(2*np.pi),length=sb2_2pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=flux_freq2/(2*np.pi),length=sb2_2pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[1] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[1][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(140)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.9817721891758916)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.43,0.45,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(150)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband EF Rabi 1 pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    ef_flux_freq1 = H0.eigenstates()[0][5] - H0.eigenstates()[0][4]
    ef_flux_freq2 = H0.eigenstates()[0][6] - H0.eigenstates()[0][4]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*sb1_ef_pi_amp,freq=flux_freq1/(2*np.pi),length=sb1_ef_pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=flux_freq1/(2*np.pi),length=sb1_ef_pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[4] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[4][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(70)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.013719714533202186)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.21,0.23,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(70)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband EF Rabi 2 pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    ef_flux_freq1 = H0.eigenstates()[0][5] - H0.eigenstates()[0][4]
    ef_flux_freq2 = H0.eigenstates()[0][6] - H0.eigenstates()[0][4]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*0.14,freq=ef_flux_freq2/(2*np.pi),length=sb2_ef_pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=ef_flux_freq2/(2*np.pi),length=sb2_ef_pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[4] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[4][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(120)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.0017415478201655303)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.13,0.15,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(120)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband EF Rabi 1 2pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    ef_flux_freq1 = H0.eigenstates()[0][5] - H0.eigenstates()[0][4]
    ef_flux_freq2 = H0.eigenstates()[0][6] - H0.eigenstates()[0][4]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*sb1_ef_2pi_amp,freq=ef_flux_freq1/(2*np.pi),length=sb1_ef_2pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=ef_flux_freq1/(2*np.pi),length=sb1_ef_2pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[4] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[4][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(120)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.0017194097885224837)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.105,0.125,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(120)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### Sideband EF Rabi 2 2pi

# %%
def Sideband_Rabi(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)
    Hz_pulse = H_Pulse(sys_para)
    
    H0 = Qobj(sys_para.H0)
    drive_freq =  H0.eigenstates()[0][1] - H0.eigenstates()[0][0]
    ef_flux_freq1 = H0.eigenstates()[0][5] - H0.eigenstates()[0][4]
    ef_flux_freq2 = H0.eigenstates()[0][6] - H0.eigenstates()[0][4]
    
    if not sweep:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*sb2_ef_2pi_amp,freq=ef_flux_freq2/(2*np.pi),length=sb2_ef_2pi_length,phase=0,ptype="square")
    else:
        Hz_pulse.add_pulse(time=0,amp=2*np.pi*amp,freq=ef_flux_freq2/(2*np.pi),length=sb2_ef_2pi_length,phase=0,ptype="square")
        
        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hz_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t
    
    def Hz_coeff(t,args=None):
        Hz_t = Hz_pulse.get_coeff(t)
        return Hz_t

    # Hamiltonian
    H0 = Qobj(sys_para.H0)
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    Hz = Qobj(sys_para.Hz_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff],[Hz,Hz_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[4] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[4][sys_para.steps-1]
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(220)
Sideband_Rabi(sys_para)
# Out:
# (Result object with mesolve data.
#  --------------------------------
#  expect = True
#  num_expect = 8, num_collapse = 0, 0.003137723864762841)

# %%
def Sideband_Rabi_sweep(sys_para):
    p_e = []
    p_f = []
    fid = []
    amp_list = np.linspace(0.06,0.08,5)
    for amp in amp_list:
        print "Simulating sweep parameter: " + str(amp)
        [output,fidelity] = Sideband_Rabi(sys_para, sweep = True, amp=amp)
        p_e.append(output.expect[1])
        p_f.append(output.expect[4])
        fid.append(fidelity)
        clear_output()
        
    #plot_sweep_result(p_g,p_e,sys_para.tlist,amp_list)
    
    return (amp_list,fid)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(220)
[amp_list,fid] = Sideband_Rabi_sweep(sys_para)
plt.plot(amp_list,fid)

# %% [markdown]
# ### GRAPE pulse simulation

# %%
control_pulse = np.load("data/drag-control.npy")
plt.plot(control_pulse[0])
plt.plot(control_pulse[1])

# %%
def GRAPE_pulse(sys_para, sweep = False, amp = 0.0):
    # Define pulses
    Hx_pulse = H_Pulse(sys_para)
    Hy_pulse = H_Pulse(sys_para)

    control_pulse = np.load("data/drag-control.npy")
    
    Hx_pulse.add_arb_pulse(control_pulse[0])
    Hy_pulse.add_arb_pulse(control_pulse[1])

        
    if not sweep:
        fig, axes = plt.subplots(1, 1, figsize=(10,6))
        plt.plot(sys_para.tlist,Hx_pulse.pulse_coeff_array)
        plt.plot(sys_para.tlist,Hy_pulse.pulse_coeff_array)
        axes.set_title('Input Pulse')

    # Get Hamiltonian pulse value at time t
    def Hx_coeff(t,args=None):
        Hx_t = Hx_pulse.get_coeff(t)
        return Hx_t

    def Hy_coeff(t,args=None):
        Hy_t = Hy_pulse.get_coeff(t)
        return Hy_t

    # Hamiltonian
    H0 = Qobj(np.diag(sys_para.ens))
    Hx = Qobj(sys_para.Hx_op)
    Hy = Qobj(sys_para.Hy_op)
    H_t = [H0, [Hx,Hx_coeff], [Hy,Hy_coeff]]
    
    state_ops = sys_para.state_operators()
    c_ops = sys_para.c_operators()

    # Run Simulation
    psi0 = state_ops[0] # start in ground cavity and excited transmon
    output = mesolve(H_t, psi0, sys_para.tlist, c_ops, state_ops ,progress_bar=True)
    clear_output()

    if not sweep:
        plot_result(output,sys_para)
    fidelity = output.expect[1][sys_para.steps-1]
    print "Pi-pulse: " + str(fidelity)
    
    return (output,fidelity)

# %%
sys_para = SystemParameters()
sys_para.update_total_time(6)
sys_para.update_pts_per_period(40)
GRAPE_pulse(sys_para)
